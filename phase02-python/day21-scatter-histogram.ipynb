# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("SALE.csv")
df
# Out:
#    Order_ID         Category Sub_Category  Sales  Profit  Quantity  Discount  \
# 0      1001        Furniture       Chairs    500      50         2      0.10
# 1      1002       Technology       Phones   1200     300         3      0.05
# 2      1003  Office Supplies      Binders    300      40         5      0.00
# 3      1004        Furniture       Tables    700      80         2      0.15
# 4      1005       Technology      Laptops   2500     600         1      0.10
# 5      1006  Office Supplies        Paper    150      20        10      0.00
# 6      1007        Furniture    Bookcases    900     120         2      0.20
# 7      1008       Technology  Accessories    400      90         4      0.05
# 8      1009  Office Supplies      Storage    350      60         3      0.10
# 9      1010        Furniture  Furnishings    250      30         6      0.00
#
#   Region
# 0  South
# 1   West
# 2   East
# 3  North
# 4   West
# 5  South
# 6   East
# 7  North
# 8   West
# 9  South

# %%
plt.scatter(df["Sales"],df["Profit"])
plt.title("Sale vs Profit")
plt.xlabel("Sale")
plt.ylabel("Profit")
plt.show()

# %%
#The scatter plot shows a positive relationship between sales and profit.
#Higher sales values generally lead to higher profits, although the relationship is not perfectly linear
#due to variations in profit margins.

# %%
plt.hist(df["Sales"], bins=5)
plt.title("Distribution of Sales")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %%
#The sales distribution is spread out with most values in the lower to mid range.
#There are a few high sales values that act as mild outliers, especially around 1200 and 2500.
