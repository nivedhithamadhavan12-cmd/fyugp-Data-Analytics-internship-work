# %%
#This notebook demonstrates my personal details

# %%
name="Nivedhitha Madhavan"
age=19
city="Angamaly"

# %%
age_in_months=age*12
age_in_days=age*365
age_in_hours=age_in_days*24
print("Age in Months:",age_in_months)
print("Age in Days:",age_in_days)
print("Age in Hours:",age_in_hours)
# Out:
# Age in Months: 228
# Age in Days: 6935
# Age in Hours: 166440

# %%
print("My name is "+ name #the error is a SyntaxError because the print statment is missing a closing paranthesis")".
# Out:
#   Cell In[8], line 1
#     print("My name is "+ name
#                              ^
# _IncompleteInputError: incomplete input
